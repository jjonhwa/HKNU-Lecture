# %%
# Local
import platform
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt
plt.rcParams['axes.unicode_minus']=False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry')

# Colab
# !pip install koreanize-matplotlib
import koreanize_matplotlib
import matplotlib.pyplot as plt
# Out:
# Unknown system... sorry
# Collecting koreanize-matplotlib
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl.metadata (992 bytes)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from koreanize-matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.17.0)
# Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 30.7 MB/s eta 0:00:00
# Installing collected packages: koreanize-matplotlib
# Successfully installed koreanize-matplotlib-0.1.1

# %%
from google.colab import drive
drive.mount("/content/drive")
# %cd /content/drive/MyDrive/HKNU-Lecture1/고급반/4차시
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/HKNU-Lecture1/고급반/4차시

# %% [markdown]
# ### 데이터 분석

# %%
import pandas as pd
path = '../../데이터/일별평균대기오염도_2023.csv'
dust_df = pd.read_csv(path, encoding="cp949")

# %%
# 일부만 출력
dust_df.head(1)
# Out:
#        측정일시 측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 0  20230101  강남구         0.024      0.024           0.6         0.004
#
#    미세먼지농도(㎍/㎥)  초미세먼지농도(㎍/㎥)
# 0         52.0          36.0

# %%
# 열 이름 출력
dust_df.columns
# Out:
# Index(['측정일시', '측정소명', '이산화질소농도(ppm)', '오존농도(ppm)', '일산화탄소농도(ppm)',
#        '아황산가스농도(ppm)', '미세먼지농도(㎍/㎥)', '초미세먼지농도(㎍/㎥)'],
#       dtype='object')

# %%
# '측정일시', '측정소명','미세먼지(㎍/㎥)' 열만 출력
dust_df2 = dust_df[['측정일시', '측정소명','미세먼지농도(㎍/㎥)']]
dust_df2.head(1)
# Out:
#        측정일시 측정소명  미세먼지농도(㎍/㎥)
# 0  20230101  강남구         52.0

# %%
# 열 이름 수정
dust_df2.columns = ['날짜', '위치', '미세먼지']
dust_df2.head(1)
# Out:
#          날짜   위치  미세먼지
# 0  20230101  강남구  52.0

# %%
# 위치가 '강동구'인 값들만 반환
dust_gu = dust_df2[dust_df2['위치']=='강동구']
dust_gu.head(1)
# Out:
#          날짜   위치  미세먼지
# 1  20230101  강동구  56.0

# %%
dust_gu.index = pd.to_datetime(dust_gu['날짜'].apply(str))
dust_gu
# Out:
#                   날짜   위치  미세먼지
# 날짜
# 2023-01-01  20230101  강동구  56.0
# 2023-01-02  20230102  강동구  26.0
# 2023-01-03  20230103  강동구  34.0
# 2023-01-04  20230104  강동구  37.0
# 2023-01-05  20230105  강동구  52.0
# ...              ...  ...   ...
# 2023-12-27  20231227  강동구  68.0
# 2023-12-28  20231228  강동구  49.0
# 2023-12-29  20231229  강동구  43.0
# 2023-12-30  20231230  강동구  42.0
# 2023-12-31  20231231  강동구  18.0
#
# [365 rows x 3 columns]

# %% [markdown]
# ### 시각화

# %%
import pandas as pd
path = '../../데이터/2018년_2차_졸업생의 진로 현황(전체).xlsx'
graduation = pd.read_excel(path, sheet_name=1)
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# 해당 열만 반환: ['지역', '정보공시 \n 학교코드', '학교명', '졸업자.2', '(특수목적고)과학고 진학자.2',  '(특수목적고)외고ㆍ국제고 진학자.2']
graduation = graduation[['지역', '정보공시 \n 학교코드', '학교명', '졸업자.2', '(특수목적고)과학고 진학자.2',  '(특수목적고)외고ㆍ국제고 진학자.2']]

# %%
# 해당 열 이름 변경
# 과학고: 과학고 진학자, 외고: 외고 진학자
graduation.columns = ['지역', '학교코드', '학교명', '졸업자', '과학고', '외고']

# %%
# 첫번째 행 제거 (필요없는 행)
graduation = graduation.drop(0)

# %%
# na값이 있는 행을 제거한다.
graduation = graduation.dropna()

# %%
# 타입 출력
graduation.dtypes
# Out:
# 지역      object
# 학교코드    object
# 학교명     object
# 졸업자     object
# 과학고     object
# 외고      object
# dtype: object

# %%
graduation['졸업자'] = pd.to_numeric(graduation['졸업자'])
graduation['과학고'] = pd.to_numeric(graduation['과학고'])
graduation['외고'] = pd.to_numeric(graduation['외고'])

# %%
# 타입 출력
graduation.dtypes
# Out:
# 지역      object
# 학교코드    object
# 학교명     object
# 졸업자      int64
# 과학고      int64
# 외고       int64
# dtype: object

# %%
# 데이터 인덱스 초기화
graduation.reset_index(drop=True, inplace=True)

# %%
# 특목고 항목 추가
graduation['특목고'] = graduation['과학고'] + graduation['외고']
graduation['특목고_비율'] = graduation['특목고'] / graduation['졸업자'] * 100
graduation.head()
# Out:
#           지역        학교코드               학교명  졸업자  과학고  외고  특목고    특목고_비율
# 0  서울특별시 성북구  S000003514    서울대학교사범대학부설중학교  234    4   5    9  3.846154
# 1  서울특별시 종로구  S000003562  서울대학교사범대학부설여자중학교  172    0   8    8  4.651163
# 2  서울특별시 강남구  S010000698             개원중학교  214    2   9   11  5.140187
# 3  서울특별시 서초구  S010000700             경원중학교  310    5   4    9  2.903226
# 4  서울특별시 강남구  S010000701             구룡중학교  256    3   4    7  2.734375

# %%
# 특목고 비율로 정렬
sp_num_20_df = graduation.sort_values('특목고', ascending=False)[:20]
sp_num_20_df.head(5)
# Out:
#                지역        학교코드      학교명  졸업자  과학고  외고  특목고     특목고_비율
# 1664      경기도 가평군  S090005419  청심국제중학교  100    0  48   48  48.000000
# 1427  경기도 안양시 동안구  S090003039    평촌중학교  441    8  34   42   9.523810
# 1407      경기도 과천시  S090003014  과천문원중학교  387    3  35   38   9.819121
# 292     서울특별시 광진구  S010002151  대원국제중학교  164    5  32   37  22.560976
# 1377  경기도 안산시 상록구  S090002694    성안중학교  309   32   4   36  11.650485

# %% [markdown]
# #### BAR 그래프

# %%
# 특목고 진학수 막대그래프
plt.figure(figsize=(11, 3))

# bar graph => bar(x,y)
plt.bar(sp_num_20_df['학교명'], sp_num_20_df['특목고'])
plt.xticks(rotation=90)

plt.show()

# %%
# 특목고 진학률 막대그래프
plt.figure(figsize=(11, 3))

# bar 그래프: plt.bar(x, height)
# • 'axis' 파라미터는 plt.bar에서 더 이상 지원되지 않으므로 제거합니다.
# • 만약 특정 축 객체(ax)를 제어하고 싶다면 fig, ax = plt.subplots()를 사용하세요.
plt.bar(
    sp_num_20_df['학교명'],    # x축: 학교명
    sp_num_20_df['특목고_비율']  # y축: 특목고 진학률
)

# x축 눈금 라벨 회전
plt.xticks(rotation=90)

# (선택) y축 범위를 지정하고 싶다면, 예를 들어 0~100%로
# plt.ylim(0, 100)

plt.show()

# %%
# 과고, 특목고 진학수 막대그래프 (데이터 2개)
plt.figure(figsize=(11, 3))

# bar graph => bar(x,y)
plt.bar(range(0, len(sp_num_20_df)), sp_num_20_df['특목고'], width=0.4)
# bar 2개일 때, 겹치지 않게 하기 위해 x축에 0.4를 더해줌
# range(0, len(sp_num_20_df)) => list 이므로 0.4를 더하기 위해 series로 변환
plt.bar(pd.Series(range(0, len(sp_num_20_df))) + 0.4, sp_num_20_df['과학고'], width=0.4)

plt.xticks(range(0, len(sp_num_20_df)), sp_num_20_df['학교명'], rotation=90)

plt.show()

# %%
# 외고, 과학고, 특목고 진학수 막대그래프 (데이터 3개)
plt.figure(figsize=(11, 3))

x = range(0, len(sp_num_20_df))
plt.bar(x, sp_num_20_df['특목고'], width=0.3, label='특목고')
plt.bar(pd.Series(x) + 0.3, sp_num_20_df['과학고'], width=0.3, label='과학고')
plt.bar(pd.Series(x) + 0.6, sp_num_20_df['외고'], width=0.3, label='외고')
plt.legend()

plt.xticks(x, sp_num_20_df['학교명'], rotation=90)

plt.show()

# %%
# 세로방향 막대그래프
plt.figure(figsize=(5, 8))

# barh(y, x)
plt.barh(sp_num_20_df['학교명'], sp_num_20_df['과학고'])

plt.show()

# %% [markdown]
# #### scatter (산포도)

# %%
# 산포도(scatter plot)를 그리기 위해 필요한 설정과 함수 사용 예시입니다.

# Figure 크기 설정: 가로 11인치, 세로 5인치 크기의 새로운 캔버스 생성
plt.figure(figsize=(11, 5))

# 산포도 그리기:
# • x 값: 과학고 진학자 수 (sp_num_20_df['과학고'])
# • y 값: 외고 진학자 수 (sp_num_20_df['외고'])
# • c 파라미터: 점 색상을 '특목고_비율' 데이터로 표현
# • cmap: 색상 맵으로 'GnBu' 사용 (녹색-파란색 계열)
# • s 파라미터: 점 크기를 '졸업자' 수로 설정
plt.scatter(
    sp_num_20_df['과학고'],          # x축 데이터
    sp_num_20_df['외고'],            # y축 데이터
    c=sp_num_20_df['특목고_비율'],    # 색상 매핑에 사용할 값
    cmap='GnBu',                     # 색상 맵 설정
    s=sp_num_20_df['졸업자']         # 각 점의 크기 설정
)

# 컬러바(colorbar) 추가:
# c 파라미터로 지정한 '특목고_비율' 값이 어떤 색상으로 매핑되었는지 보여줍니다.
plt.colorbar()

# 수직선(vline) 추가:
# 과학고 진학자의 평균값 위치에 빨간색 점선으로 기준선 표시
plt.axvline(
    sp_num_20_df['과학고'].mean(),  # x 위치: 과학고 진학자 평균
    color='red',                   # 선 색상: 빨간색
    ls=':'                         # 선 스타일: 점선
)

# 수평선(hline) 추가:
# 외고 진학자의 평균값 위치에 초록색 점선으로 기준선 표시
plt.axhline(
    sp_num_20_df['외고'].mean(),   # y 위치: 외고 진학자 평균
    color='green',                 # 선 색상: 초록색
    ls=':'                         # 선 스타일: 점선
)

# x축 레이블 설정
plt.xlabel('과고 진학자')

# y축 레이블 설정
plt.ylabel('외고 진학자')

# 그래프 출력
plt.show()

# %% [markdown]
# #### countplot
#
# - seaborn
#     - matplotlib 의 추가 패키지
#     - matplotlib 의 옵션이 다 들어감
#     - 좀 더 편하게 여러 그래프를 그리게 해줌
# - countplot => sns.countplot(data=df, x='카운팅 할 컬럼명', hue='카운팅 할 컬럼명2'
#     - hue는 1개만 지정 가능
#     - 단점 : 커스터마이징이 어렵다

# %%
import seaborn as sns

def temp(x):
    return x.split(' ')[0]

# 시도별 학교 개수
graduation['시도'] = graduation['지역'].apply(temp)

plt.figure(figsize=(11, 5))
sns.countplot(data=graduation, x='시도')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### boxplot

# %%
# boxplot => boxplot(data=df, x='카테고리가 될 컬럼명', y='수치가 될 컬럼명')

# 시도별(카테고리) 특목고 진학률(수치) 체크

plt.figure(figsize=(12, 5))

sns.boxplot(data=graduation, x='시도', y='특목고_비율')
plt.xticks(rotation=45)

plt.ylim(-5, 20)  # y축 최소, 최대값 지정
#plt.xlim(5, 13)  # x

plt.show()

# %% [markdown]
# #### displot

# %%
# Q. 서울특별시와 경기도의 졸업생 데이터 분포도 비교

# 서울, 경기도로 필터링
seoul_df = graduation[graduation['시도']=='서울특별시']
gg_df = graduation[graduation['시도']=='전라남도']

# 그래프 그리기
plt.figure(figsize=(15, 5))

sns.distplot(seoul_df['졸업자'], label='서울 졸업자 수')
sns.distplot(gg_df['졸업자'], color='green', label='전라남도 졸업자 수')
plt.axvline(seoul_df['졸업자'].mean(), color='blue', ls=':')
plt.axvline(gg_df['졸업자'].mean(), color='green', ls=':')
plt.legend()

plt.show()
# Out:
# /tmp/ipython-input-27-2992802535.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(seoul_df['졸업자'], label='서울 졸업자 수')
# /tmp/ipython-input-27-2992802535.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(gg_df['졸업자'], color='green', label='전라남도 졸업자 수')

# %%
graduation
# Out:
#                 지역        학교코드               학교명  졸업자  과학고  외고  특목고    특목고_비율  \
# 0        서울특별시 성북구  S000003514    서울대학교사범대학부설중학교  234    4   5    9  3.846154
# 1        서울특별시 종로구  S000003562  서울대학교사범대학부설여자중학교  172    0   8    8  4.651163
# 2        서울특별시 강남구  S010000698             개원중학교  214    2   9   11  5.140187
# 3        서울특별시 서초구  S010000700             경원중학교  310    5   4    9  2.903226
# 4        서울특별시 강남구  S010000701             구룡중학교  256    3   4    7  2.734375
# ...            ...         ...               ...  ...  ...  ..  ...       ...
# 3417   제주특별자치도 제주시  S170000838             오름중학교  193    0   5    5  2.590674
# 3418   제주특별자치도 제주시  S170000844             탐라중학교  298    1   1    2  0.671141
# 3419   제주특별자치도 제주시  S170000512            제주영지학교   12    0   0    0  0.000000
# 3420   제주특별자치도 제주시  S170000513            제주영송학교   21    0   0    0  0.000000
# 3421  제주특별자치도 서귀포시  S170000790           서귀포온성학교    9    0   0    0  0.000000
#
#            시도
# 0       서울특별시
# 1       서울특별시
# 2       서울특별시
# 3       서울특별시
# 4       서울특별시
# ...       ...
# 3417  제주특별자치도
# 3418  제주특별자치도
# 3419  제주특별자치도
# 3420  제주특별자치도
# 3421  제주특별자치도
#
# [3422 rows x 9 columns]

# %%
# scatter + sns.regplot()
# sns.regplot() => 회귀선(추세선) 그려진 산포도 출력
#               => 보통 산포도는 scatter를 이용한다 (옵션이 더 많아서) => regplot()의 옵션 중 scatter=False를 설정하여 점을 해제함

plt.figure(figsize=(11, 5))

plt.scatter(sp_num_20_df['과학고'], sp_num_20_df['외고'], c=sp_num_20_df['특목고_비율'])
sns.regplot(data=sp_num_20_df, x='과학고', y='외고', scatter=False, color='red')  # 회귀선(추세선) 출력

plt.show()

# %% [markdown]
# #### pairplot

# %%
# pairplot => dataframe 안의 연속적인 숫자 데이터 간 관계를 모두 보여 줌
sns.pairplot(graduation, hue='시도')
